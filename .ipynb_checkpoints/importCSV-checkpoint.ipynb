# %%
#Importing libraries 
import pandas as pd
import numpy as np

#Read csv files into a pandas dataframe 
#df = pd.read_csv("/Users/aniketsingh/SeniorProject/site_weather.csv")


#Making a list of missing values types
missingValues = ["n/a", "na", " ", "__"]
data = pd.read_csv("./data/site_weather.csv", na_values = missingValues)

data.rename(columns = {'Unnamed: 0': 'Timestamp'}, inplace = True)
#First few rows
print(data.head())



#Total missing values for each feature 
print("-------------Here are the missing values----------")
print(data.isnull().sum())
# Out:
#                    Timestamp  air_temp_set_1  air_temp_set_2  \
# 0  2018-01-01 00:00:00+00:00          11.565          11.465
# 1  2018-01-01 00:30:00+00:00          11.515          11.460
# 2  2018-01-01 01:00:00+00:00          11.030          11.080
# 3  2018-01-01 01:30:00+00:00          10.750          10.785
# 4  2018-01-01 02:00:00+00:00          10.785          10.835
#
#    dew_point_temperature_set_1d  relative_humidity_set_1  \
# 0                         8.120                   79.585
# 1                         8.160                   80.060
# 2                         8.015                   81.850
# 3                         7.975                   83.150
# 4                         7.975                   82.950
#
#    solar_radiation_set_1
# 0                 66.290
# 1                 36.525
# 2                  4.130
# 3                  0.120
# 4                  0.000
# -------------Here are the missing values----------
# Timestamp                         0
# ...

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
sns.lineplot(x="Timestamp", y="air_temp_set_1", data=data[0:100])

# %%
from datetime import datetime
import pytz

#utc = pytz.utc
#eastern = pytz.timezone('US/Eastern')

#datetime1 = datetime.strptime(data['Timestamp'], "%Y-%m-%dT%H:%M:%S")

# First, tell Python what timezone that string was in (you said Eastern)
#eastern_time = eastern.localize(datetime1)

# Then convert it from Eastern to UTC
#utc_time = eastern_time.astimezone(utc)#
data['Timestamp'] = pd.to_datetime(data.Timestamp)
data.set_index('Timestamp', inplace=True)
data.index = data.index.tz_localize('UTC').tz_convert('US/Eastern')
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d90abf3389bc> in <module>
#      14 data['Timestamp'] = pd.to_datetime(data.Timestamp)
#      15 data.set_index('Timestamp', inplace=True)
# ---> 16 data.index = data.index.tz_localize('UTC').tz_convert('US/Eastern')
#      17 data.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in f(self, *args, **kwargs)
#      97         def _create_delegator_method(name):
#      98             def f(self, *args, **kwargs):
# ---> 99                 return self._delegate_method(name, *args, **kwargs)
#     100
#     101             f.__name__ = name
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/datetimelike.py in _delegate_method(self, name, *args, **kwargs)
#     903
#     904     def _delegate_method(self, name, *args, **kwargs):
# ...
